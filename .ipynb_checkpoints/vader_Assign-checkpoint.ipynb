# %%
import json

# %%
# twitterscraper "#msft OR #microsoft  OR #windows OR #azure OR #xbox lang:en filter:verified" -bd 2019-01-01 -p 50 -o tweets_msft.json -ow
with open('tweets_msft18-19.json', 'r') as f:
    tweets = json.load(f, encoding = 'utf-8')

# %%
print(len(tweets))
print(len(tweets[0]))
print(tweets[0].keys())
# Out:
# 28347
# 10
# dict_keys(['fullname', 'html', 'id', 'likes', 'replies', 'retweets', 'text', 'timestamp', 'url', 'user'])

# %%
[tweet.pop('fullname') for tweet in tweets]
[tweet.pop('html') for tweet in tweets]
[tweet.pop('id') for tweet in tweets]
[tweet.pop('likes') for tweet in tweets]
[tweet.pop('replies') for tweet in tweets]
[tweet.pop('retweets') for tweet in tweets]
[tweet.pop('url') for tweet in tweets]
[tweet.pop('user') for tweet in tweets]
# Out:
# ['Azure',
#  'Xbox',
#  'Azure',
#  'AragonResearch1',
#  'NLintheUSA',
#  'CSOonline',
#  'Xbox',
#  'TJRamini',
#  'Azure',
#  'BigDataExpo',
#  'AzureSupport',
#  'hillharper',
#  'CapeTalk',
#  'Radio702',
#  'VisualStudio',
#  'jfrog',
#  'ID_Xbox',
#  'MicrosoftTechNZ',
#  'Azure',
#  'MS_ITPro',
#  'Azure',
#  'Xbox',
#  'Azure',
#  'AragonResearch1',
#  'NLintheUSA',
#  'CSOonline',
#  'Xbox',
#  'TJRamini',
#  'Azure',
#  'BigDataExpo',
#  'AzureSupport',
#  'hillharper',
#  'CapeTalk',
#  'Radio702',
#  'VisualStudio',
#  'jfrog',
#  'ID_Xbox',
#  'MicrosoftTechNZ',
#  'Azure',
#  'MS_ITPro',
#  'msdevCA',
#  'ComputerWeekly',
#  'CSOonline',
#  'ParallelsMac',
#  'PeninsulaQatar',
#  'XboxAmbassadors',
#  'Azure',
#  'MSCloud',
#  'singhabhinav',
#  'MSAdvAnalytics',
#  'majornelson',
#  'NLintheUSA',
#  'MSFTBusinessMEA',
#  'MS_ITProCA',
#  'Azure',
#  'VisualStudio',
#  'TrueAchievement',
#  'microsoftgulf',
#  'cdkeyscom',
#  'Microsoft_Saudi',
#  'dotnet',
#  'redgate',
#  'BlueJeansNet',
#  'msdev',
#  'Chahali',
#  'msdev',
#  'Telerik',
#  'nintendolife',
#  'WhichTech',
#  'weareosd',
#  'AzureSupport',
#  'DellEMCProtect',
#  'ians_india',
#  'purassan',
#  'saramayhew',
#  'ians_india',
#  'nintendolife',
#  'MicrosoftASIA',
#  'LBugnion',
#  'MSCloud',
#  'worldnewsdotcom',
#  'MSCloud',
#  'Azure',
#  'McAfee_Help',
#  'Azure',
#  'PDPgaming',
#  'windowsserver',
#  'DellCaresPRO',
#  'KendoUI',
#  'KendoUI',
#  'Azure',
#  'HOT97',
#  'Azure',
#  'CSOonline',
#  'EconomicTimes',
#  'Telerik',
#  'TripwireInc',
#  'lopezgovlaw',
#  'GDNonline',
#  'WANdisco',
#  'mnaEN',
#  'MicrosoftTechNZ',
#  'Mimecast',
#  'VisualStudio',
#  'EconomicTimes',
#  'gigaomresearch',
#  'msPartner',
#  'LouisSerge',
#  'StaySafeOnline',
#  'PacktPub',
#  'msdev',
#  'ID_Xbox',
#  'DellCaresPRO',
#  'CSOonline',
#  'XboxQwik',
#  'Fasthosts',
#  'tsecrime',
#  'ComputerWeekly',
#  'mnaEN',
#  'QuickStartIntel',
#  'CSOonline',
#  'AzureSupport',
#  'TripwireInc',
#  'siliconrepublic',
#  'SFdirewolf',
#  'FinancialXpress',
#  'Nextclouders',
#  'msdevUK',
#  'RCDeSports',
#  'PeninsulaQatar',
#  'neirajones',
#  'ians_india',
#  'neirajones',
#  'Plus500',
#  'TripwireInc',
#  'MicrosoftASIA',
#  'pushsquare',
#  'Azure',
#  'ians_india',
#  'MicrosoftNZ',
#  'MystikGunn',
#  'vesahakkinen',
#  'TechRepublic',
#  'MicrosoftIndia',
#  'bbcsinhala',
#  'Health_IT',
#  'MS_ITPro',
#  'MicrosoftASIA',
#  'ASUSUSA',
#  'ZeeBusiness',
#  'Microsoft_SG',
#  'MYMicrosoft',
#  'Lennar',
#  'mnaEN',
#  'ID_Xbox',
#  'jaydestro',
#  'pushsquare',
#  'Stefan24Frei',
#  'TripwireInc',
#  'UMGGaming',
#  'Smarttech01',
#  'Azure',
#  'Xbox',
#  'Azure',
#  'marc_smith',
#  'CISecurity',
#  'AzureSupport',
#  'Azure',
#  'Warface',
#  'kaspersky',
#  'DellCaresPRO',
#  'MS_ITPro',
#  'GameTyrant',
#  'jshuey',
#  'Mindjet',
#  'Azure',
#  'MSFTImagine',
#  'Cex',
#  'TripwireInc',
#  'bigmarker',
#  'TheGirlsOnGames',
#  'Telerik',
#  'XboxCanada',
#  'leahjewer',
#  'MicrosoftSB',
#  'WAOK',
#  'Warface',
#  'VisualStudio',
#  'TrueAchievement',
#  'Telerik',
#  'AzureSupport',
#  'TripwireInc',
#  'Microsoft_Saudi',
#  'craigbigbro1',
#  'UKFast',
#  'AdeAdepitan',
#  'redgate',
#  'ProfOfMusic',
#  'annie_parker',
#  'ProfOfMusic',
#  'saramayhew',
#  'TrueAchievement',
#  'leahjewer',
#  'VisualStudio',
#  'Azure',
#  'MSFTDynamics365',
#  'Azure',
#  'dt_next',
#  'MSFTImagine',
#  'AzureDevOps',
#  'Health_IT',
#  'HPE_Alliances',
#  'TrueAchievement',
#  'TripwireInc',
#  'msdev',
#  'Azure',
#  'DellCares',
#  'AzureSupport',
#  'Azure',
#  'DownloadNow',
#  'VisualStudio',
#  'msdevCA',
#  'msdev',
#  'DownloadNow',
#  'Telerik',
#  'dchou1107',
#  'Azure',
#  'gigaomresearch',
#  'marc_smith',
#  'AnglianHome',
#  'VisualStudio',
#  'ComputerWeekly',
#  'msdevUK',
#  'a2hosting',
#  'worldsteel',
#  'VisualStudio',
#  'BlueJeansNet',
#  'dimitribest',
#  'ITPro',
#  'vigorthegame',
#  'ians_india',
#  'YourStoryCo',
#  'HPE_UKI',
#  'TechNetUK',
#  'ListerTF',
#  'softonic',
#  'MystikGunn',
#  'PlayBlackDesert',
#  'softonic',
#  'MYMicrosoft',
#  'MSCloud',
#  'Azure',
#  'MS_ITPro',
#  'CBTNuggets',
#  'Azure',
#  'Azure',
#  'CBTNuggets',
#  'larrykim',
#  'Azure',
#  'CBTNuggets',
#  'ProfOfMusic',
#  'Azure',
#  'MrProWestie',
#  'Azure',
#  'Game_Revolution',
#  'Xbox',
#  'jshuey',
#  'msdev',
#  'redgate',
#  'CSOonline',
#  'Computerworld',
#  'simonsquibb',
#  'WhichTech',
#  'ians_india',
#  'ProfOfMusic',
#  'MSFTDynamics365',
#  '99acresIndia',
#  'Azure',
#  'PowerApps',
#  'CBTNuggets',
#  'windowsserver',
#  'Azure',
#  'MS_ITPro',
#  'CBTNuggets',
#  'MSFTImagine',
#  'MSCloud',
#  'CBTNuggets',
#  'WindowsUK',
#  'satinephoenix',
#  'Apress',
#  'Azure',
#  'Azure',
#  'CSOonline',
#  'gigaomresearch',
#  'Azure',
#  'MaBialecki',
#  'TechNetUK',
#  'demimckinney',
#  'DellCares',
#  'McAfee_Help',
#  'SQLServer',
#  'MystikGunn',
#  'MSPowerBI',
#  'microsoftgulf',
#  'PerfectLegend',
#  'MSCloud',
#  'MS_ITPro',
#  'scroll_in',
#  'onlineclock',
#  'msPartner',
#  'CBTNuggets',
#  'Azure',
#  'Gfinity',
#  'Azure',
#  'MicrosoftRI',
#  'CSOonline',
#  'Azure',
#  'msPartner',
#  'Chahali',
#  'CBTNuggets',
#  'Talend',
#  'Xbox',
#  'BrookhavenInfo',
#  'AvanadeInc',
#  'Azure',
#  'Computerworld',
#  'ParallelsMac',
#  'Azure',
#  'mspartnersuk',
#  'Azure',
#  'Xbox',
#  'CBTNuggets',
#  'GlobalKnowledge',
#  'StanfordLaw',
#  'MicrosoftUK',
#  'CSOonline',
#  'SaudiProjectEN',
#  'teamBlindapp',
#  'Checkmarx',
#  'trifonic',
#  'brianleewhite',
#  'redgate',
#  'ComputerWeekly',
#  'AMAnet',
#  'DylanTaylorEh',
#  'VisualStudio',
#  'UKFast',
#  'DylanTaylorEh',
#  'DellCares',
#  'TrueAchievement',
#  'ComputerWeekly',
#  'Computerworld',
#  'AzureSupport',
#  'Chahali',
#  'ExpressTechie',
#  'ComputerBase',
#  'MSPowerBI',
#  'microsoftgulf',
#  'MicrosoftIndia',
#  '91mobiles',
#  'MicrosoftIndia',
#  'MystikGunn',
#  'Microsoft_Saudi',
#  'MSFTBusinessMEA',
#  'ProfOfMusic',
#  'MS_ITPro',
#  'MicrosoftASIA',
#  'MicrosoftAUDev',
#  'MSCloud',
#  'VisualStudio',
#  'CBTNuggets',
#  'Azure',
#  'MSWindowsITPro',
#  'Azure',
#  'VisualStudio',
#  'Gfinity',
#  'druvainc',
#  'MSCloud',
#  'MS_ITPro',
#  'Azure',
#  'Azure',
#  'cloudpassage',
#  'Azure',
#  'AzureSupport',
#  'barracuda',
#  'Azure',
#  'chef',
#  'Dell',
#  'McAfee_Help',
#  'DHern_30',
#  'TechNetUK',
#  'AlexHPforQVC',
#  'Azure',
#  'mspartnersuk',
#  'MSCloud',
#  'Xbox',
#  'ID_Xbox',
#  'statnews',
#  'CSOonline',
#  'Azure',
#  'XboxAmbassadors',
#  'MSFTImagine',
#  'sqlpass',
#  'msPartner',
#  'TripwireInc',
#  'MSAdvAnalytics',
#  'HPE_HybridCloud',
#  'Azure',
#  'ClaraChooi',
#  'ComputerWeekly',
#  'ComputerWeekly',
#  'MicrosoftUK',
#  'DellCaresPRO',
#  'SQLServer',
#  'redgate',
#  'globalsign',
#  'MS_ITPro',
#  'msdevUK',
#  'MicrosoftUK',
#  'AzureSupport',
#  'Imperva',
#  'Chahali',
#  'MS_ITPro',
#  'golem',
#  'VaticanNews',
#  'MicrosoftUK',
#  'microsoftgulf',
#  'redgate',
#  'PlayBlackDesert',
#  'MicrosoftASIA',
#  'microsoftgulf',
#  'FinalFantasy',
#  'TripwireInc',
#  'MSCloud',
#  'annie_parker',
#  'CBTNuggets',
#  'TEKsystems',
#  'Azure',
#  'pushsquare',
#  'SQLServer',
#  'Computerworld',
#  'barracuda',
#  'FinalFantasy',
#  'SQLServer',
#  'FinalFantasy',
#  'Checkmarx',
#  'Gfinity',
#  'TripwireInc',
#  'Azure',
#  'Telerik',
#  'Azure',
#  'OneNoteEDU',
#  'Philanthropy411',
#  'CBTNuggets',
#  'ASTROGamingUK',
#  'Azure',
#  'CSOonline',
#  'AMAnet',
#  'Azure',
#  'Computerworld',
#  'MicrosoftDesign',
#  'ComputerWeekly',
#  'MSFTImagine',
#  'KCOMhome',
#  'Azure',
#  'MSAdvAnalytics',
#  'IBMEurope',
#  'CSOonline',
#  'bigmarker',
#  'pushsquare',
#  'DeadByBHVR',
#  'TripwireInc',
#  'Azure',
#  'MSFTImagine',
#  'windowsserver',
#  'McAfee_Help',
#  'AzureDevOps',
#  'jonholmes1',
#  'microsoftgulf',
#  'MSFTBusinessMEA',
#  'Telerik',
#  'ComputerWeekly',
#  'msdev',
#  'microsoftgulf',
#  'DellCares',
#  'Fujitsu_Global',
#  'DellCaresPRO',
#  'AzureSupport',
#  'ASTROGamingUK',
#  'Gfinity',
#  'ListerTF',
#  'helpnetsecurity',
#  'MSFTImagine',
#  'MystikGunn',
#  'microsofttech',
#  'threatintel',
#  'Softpedia',
#  'microsoftgulf',
#  'ADATATechnology',
#  'theDTG',
#  'koeitecmoeurope',
#  'MicrosoftASIA',
#  'microsoftgulf',
#  'Zensar',
#  'worldnewsdotcom',
#  'ians_india',
#  'threatintel',
#  'MicrosoftAUDev',
#  'Azure',
#  'MSFTDynamics365',
#  'Azure',
#  'MicrosoftFlow',
#  'Azure',
#  'CBTNuggets',
#  'VisualStudio',
#  'Azure',
#  'cloudpassage',
#  'MicrosoftAUDev',
#  'alteryx',
#  'SQLServer',
#  'Azure',
#  'doctorsim',
#  'MSCloud',
#  'KendoUI',
#  'ID_Xbox',
#  'Docker',
#  'Azure',
#  'Telerik',
#  'AzureSupport',
#  'MSAdvAnalytics',
#  'Azure',
#  'RSMUSLLP',
#  'ID_Xbox',
#  'MS_ITPro',
#  'CBTNuggets',
#  'Azure',
#  'mspartnersuk',
#  'thezdi',
#  'Mindjet',
#  'NicolaPosener',
#  'ID_Xbox',
#  'SQLServer',
#  'MS_ITProCA',
#  'Azure',
#  'CapeTalk',
#  'Radio702',
#  'LightningPandas',
#  'TechNetUK',
#  'CapeTalk',
#  'Radio702',
#  'msdev',
#  'ID_Xbox',
#  'CapeTalk',
#  'Gamekings',
#  'Azure',
#  'Radio702',
#  'UKFast',
#  'indiatimes',
#  'SPTechCon',
#  'barracuda',
#  'DellCares',
#  'SPTechCon',
#  'Chahali',
#  'TrueAchievement',
#  'microsoftgulf',
#  'microsofteduk',
#  'MicrosoftUK',
#  'AzureSupport',
#  'RobotShop',
#  'microsofteduk',
#  'MicrosoftUK',
#  'microsofttech',
#  'MSFTImagine',
#  '91mobiles',
#  'ians_india',
#  'XboxQwik',
#  'MystikGunn',
#  'MicrosoftASIA',
#  'ians_india',
#  'dt_next',
#  'ParallelsMac',
#  'windog',
#  'TrueAchievement',
#  'DellEMCProtect',
#  'schisam',
#  'cottagelife',
#  'BennyCentral',
#  'MS_ITPro',
#  'Azure',
#  'HPE_Alliances',
#  'MS_ITPro',
#  'Azure',
#  'VisualStudio',
#  'barracuda',
#  'Azure',
#  'CBTNuggets',
#  'Chahali',
#  'Azure',
#  'cloudpassage',
#  'skillsmatter',
#  'AzureSupport',
#  'redgate',
#  'AvanadeInc',
#  'PeoplesAstro',
#  'Azure',
#  'Azure',
#  'barracuda',
#  'MicrosoftSB',
#  'CSOonline',
#  'MSFTDynamics365',
#  'VisualStudio',
#  'gigaomresearch',
#  'gigaom',
#  'pluralsight',
#  'Azure',
#  'SPTechCon',
#  'TechJuicePk',
#  'MicrosoftSB',
#  'MS_ITPro',
#  'MicrosoftUK',
#  'SPTechCon',
#  'ComputerWeekly',
#  'lopezgovlaw',
#  'KendoUI',
#  'MicrosoftUK',
#  'AzureSupport',
#  'ARYNEWSOFFICIAL',
#  'MicrosoftUK',
#  'CloudExpo',
#  'itworldca',
#  'microsofttech',
#  'MicrosoftSB',
#  'ians_india',
#  'dt_next',
#  'MS_ITPro',
#  'MystikGunn',
#  'helpnetsecurity',
#  'Softpedia',
#  'DellCaresPRO',
#  'MSCloud',
#  'MSCloud',
#  'Azure',
#  'MSAdvAnalytics',
#  'MSCloud',
#  'mkfresh1',
#  'msdev',
#  'Azure',
#  'ColorOfChange',
#  'Azure',
#  'Azure',
#  'gigaomresearch',
#  'Warface',
#  'vigorthegame',
#  'CloudExpo',
#  'Fujitsu_Global',
#  'MystikGunn',
#  'MicrosoftASIA',
#  'KirkDBorne',
#  'moesalem92',
#  'Azure',
#  'Azure',
#  'Azure',
#  'Azure',
#  'Computerworld',
#  'DavidLinthicum',
#  'MSAdvAnalytics',
#  'SQLServer',
#  'WindowsUK',
#  'Azure',
#  'tsecrime',
#  'wizzouk',
#  'BennyCentral',
#  'NetAppME',
#  'softonic',
#  'vigorthegame',
#  'ProfOfMusic',
#  'Zensar',
#  'ProfOfMusic',
#  'neirajones',
#  'Azure',
#  'Hyperkin',
#  'ID_Xbox',
#  'ID_Xbox',
#  'Azure',
#  'DownloadNow',
#  'Docker',
#  'InsightEnt',
#  'InsightEnt',
#  'jaydestro',
#  'Azure',
#  'TEKsystems',
#  'Azure',
#  'FinancialXpress',
#  'AshleyO2Go',
#  'CSOonline',
#  'ID_Xbox',
#  'Azure',
#  'msPartner',
#  'Azure',
#  'XboxQwik',
#  'SPTechCon',
#  'MediaSmarts',
#  'ID_Xbox',
#  'MSFTImagine',
#  'PDPgaming',
#  'msPartner',
#  'GloZell',
#  'ID_Xbox',
#  'Talend',
#  'Azure',
#  'msPartner',
#  'CSOonline',
#  'ID_Xbox',
#  'bigmarker',
#  'DeadByBHVR',
#  'Telerik',
#  'SQLServer',
#  'BGRIndia',
#  'HPE_HybridCloud',
#  'CenturyLink',
#  'tsecrime',
#  'msdevCA',
#  'MSFTBusinessUK',
#  'Apress',
#  'MrAhmadAwais',
#  'Game_Revolution',
#  'MicrosoftUK',
#  'ExpressTechie',
#  'eToro',
#  'MicrosoftUK',
#  'eToro',
#  'neirajones',
#  'microsofttech',
#  'RakutenUK',
#  'MicrosoftUK',
#  'DellCaresPRO',
#  'msdevUK',
#  'MS_ITPro',
#  'helpnetsecurity',
#  'Fujitsu_Global',
#  'ASTROGaming',
#  'dt_next',
#  'ians_india',
#  'MS_ITPro',
#  'windowsserver',
#  'Azure',
#  'ID_Xbox',
#  'MSCloud',
#  'msPartner',
#  'HPE_HybridCloud',
#  'SQLServer',
#  'Fortinet',
#  'Azure',
#  'VisualStudio',
#  'Azure',
#  'windowsserver',
#  'Docker',
#  'WANdisco',
#  'AzureDevOps',
#  'MicrosoftDesign',
#  'Azure',
#  'Azure',
#  'Azure',
#  'SharePoint',
#  'msdev',
#  'AzureSupport',
#  'Azure',
#  'SHI_Intl',
#  'ProfOfMusic',
#  'WANdisco',
#  'Azure',
#  'gigaom',
#  'SPTechCon',
#  'MsftSecIntel',
#  'Azure',
#  'msPartner',
#  'ComputerWeekly',
#  'DavidLinthicum',
#  'NetAppUK',
#  'MSFTImagine',
#  'Azure',
#  'Azure',
#  'MicrosoftSB',
#  'msPartner',
#  'cdkeyscom',
#  'lopezgovlaw',
#  'msdev',
#  'TSystemsUK',
#  'Azure',
#  'MSFTMechanics',
#  'EECallum',
#  'ComputerWeekly',
#  'mnaEN',
#  'VisualStudio',
#  'CSOonline',
#  'DellCares',
#  'msdev',
#  'pctechmagazine',
#  'MicrosoftUK',
#  'Warface',
#  'cdkeyscom',
#  'Telerik',
#  'Talend',
#  'KhalidAlrazooqi',
#  'AzureSupport',
#  'UKFast',
#  'Microsoft_Saudi',
#  'WANdisco',
#  'MicrosoftASIA',
#  'report_real',
#  'ZeeBusiness',
#  'MS_ITPro',
#  'BGRIndia',
#  'ians_india',
#  'msPartner',
#  'SnapLogic',
#  'Azure',
#  'Azure',
#  'softonic',
#  'MSCloud',
#  'MSFTDynamics365',
#  'MicrosoftASIA',
#  'DailyO_',
#  'MSCloud',
#  'Azure',
#  'BrianBoitano',
#  'Azure',
#  'arabnews',
#  'statnews',
#  'jfrog',
#  'Game_Revolution',
#  'Azure',
#  'CSOonline',
#  'Azure',
#  'Azure',
#  'divorcecourt',
#  'msdev',
#  'AzureSupport',
#  'moneypit',
#  'CSOonline',
#  'datadoghq',
#  'mahesh10feb',
#  'DavidLinthicum',
#  'MS_ITProCA',
#  'ID_Xbox',
#  'MS_ITPro',
#  'RogerCraigSmith',
#  'ID_Xbox',
#  'Azure',
#  'CloudExpo',
#  'AudiOfficial',
#  'MSFTBusinessUK',
#  'MicrosoftSB',
#  'ComputerWeekly',
#  'ID_Xbox',
#  'msPartner',
#  'HPE_UKI',
#  'ComputerWeekly',
#  'ID_Xbox',
#  'Azure',
#  'Cloudpro',
#  'MicrosoftSB',
#  'windowsserver',
#  'CSOonline',
#  'Telerik',
#  'EdCast',
#  'ID_Xbox',
#  'msdevUK',
#  'BennyCentral',
#  'ComputerWeekly',
#  'ComputerWeekly',
#  'BiIndia',
#  'cdkeyscom',
#  'DP_CyberCrime',
#  'CSOonline',
#  'WhichTech',
#  'AzureSupport',
#  'ListerTF',
#  'UKFast',
#  'SpotifyArabia',
#  'MystikGunn',
#  'microsofttech',
#  'DailyO_',
#  'Microsoft_Saudi',
#  'annie_parker',
#  'lopezgovlaw',
#  'MicrosoftASIA',
#  'ProfOfMusic',
#  'Azure',
#  'MS_ITPro',
#  'TechRepublic',
#  'Health_IT',
#  'Elamite',
#  'MakeUseOf',
#  'Azure',
#  'msdevCA',
#  'Azure',
#  'DownloadNow',
#  'app_trigger',
#  'PDPgaming',
#  'Computerworld',
#  'bWoStevie',
#  'MicrosoftAUDev',
#  'TrueAchievement',
#  'CISecurity',
#  'Azure',
#  'Windows',
#  'MS_ITPro',
#  'Azure',
#  'PitchBook',
#  'Azure',
#  'Azure',
#  'DownloadNow',
#  'MikeOlbinski',
#  'Telerik',
#  'AzureSupport',
#  'Warface',
#  'Azure',
#  'MS_ITPro',
#  'Docker',
#  'Azure',
#  'heiseonline',
#  'msdevCA',
#  'Azure',
#  'msdevUK',
#  'WWG',
#  'TechNetUK',
#  'sqlpass',
#  'Computerworld',
#  'MakeUseOf',
#  'BANGShowbiz',
#  'AvanadeInc',
#  'ComputerWeekly',
#  'wikitude',
#  'windowsserver',
#  'UKFast',
#  'microsofteduk',
#  'SYFYWIRE',
#  'BSAnews',
#  'DownloadNow',
#  'Fujitsu_Global',
#  'MicrosoftSB',
#  'MSFTBusinessUK',
#  'TrueAchievement',
#  'RobotShop',
#  'chriscapossela',
#  'chriscapossela',
#  'AzureSupport',
#  'Spiceworks',
#  'chrispugh3',
#  'ians_india',
#  'Azure',
#  'TrueAchievement',
#  'microsofttech',
#  'MystikGunn',
#  'MicrosoftASIA',
#  'MicrosoftUK',
#  'skillsmatter',
#  'FinancialXpress',
#  'MSCloud',
#  'ProfOfMusic',
#  'TrueAchievement',
#  'BTVI',
#  'MS_ITPro',
#  'Azure',
#  'MS_ITPro',
#  'PeggyJ',
#  'ShannonNews8',
#  'Azure',
#  'WeAreFetch',
#  'theSeanPower',
#  'msdev',
#  'Azure',
#  'MrJoshuaGray',
#  'pushsquare',
#  'CBTNuggets',
#  'appleinsider',
#  'AzureSupport',
#  'Azure',
#  'Azure',
#  'MSFTImagine',
#  'pluralsight',
#  'skillsmatter',
#  'CSOonline',
#  'sqlpass',
#  'meetdux',
#  'redgate',
#  'Azure',
#  'OpenAtMicrosoft',
#  'chriscapossela',
#  'Quest',
#  'InsightEnt',
#  'bigmarker',
#  'DellCares',
#  'thenews_intl',
#  'Azure',
#  'DellCares',
#  'xdadevelopers',
#  'MPNCanada',
#  'Fasthosts',
#  ...]

# %%
print(tweets[0])
# Out:
# {'text': 'Watch how to troubleshoot your #VMs using #Azure Virtual machines Serial Console: http://msft.social/FjPJPi\xa0 #AzureTipsAndTricks', 'timestamp': '2019-02-21T23:30:00'}

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

analyzer = SentimentIntensityAnalyzer()

# %%
#tweet = tweets[0]
#print(tweet)
#temp = analyzer.polarity_scores(tweet.pop('text'))
#temp_tweet['vader'] = temp.pop('compound')
for tweet in tweets:
    tweet['vader'] = (analyzer.polarity_scores(tweet.get('text'))).pop('compound')

# %%
print(tweets[0])
# Out:
# {'text': 'Watch how to troubleshoot your #VMs using #Azure Virtual machines Serial Console: http://msft.social/FjPJPi\xa0 #AzureTipsAndTricks', 'timestamp': '2019-02-21T23:30:00', 'vader': 0.2023}

# %%
import numpy as np
import datetime

# %matplotlib inline
import matplotlib as plt

vaderScores = np.empty([len(tweets)])
timeStamps = np.empty([len(tweets)], dtype = datetime.datetime)
for i in range(len(tweets)):
    vaderScores[i] = tweets[i].get('vader')
    timeStamps[i] = datetime.datetime.strptime(tweets[i].get('timestamp'), '%Y-%m-%dT%H:%M:%S')
print('Mean: ' + str(np.mean(vaderScores)))
print('Standard deviation: ' + str(np.std(vaderScores)))
# Out:
# Mean: 0.23933827918298234
# Standard deviation: 0.37003352032877385

# %%
import pandas as pd

denoisedVader = vaderScores[vaderScores != 0]
vader_times = np.transpose(np.vstack((timeStamps, vaderScores)))
vader_times_Size = vader_times.shape
print(vader_times_Size)
df = pd.DataFrame(vader_times, columns=['date', 'vader'])
df.sort_values(by=['date'], ascending = True, inplace = True)

print(df.values[len(timeStamps)-1, 0])
minTime = df.values[0, 0]
maxTime = df.values[len(timeStamps)-1, 0]

daysIncluded = np.busday_count(minTime.strftime('%Y-%m-%d'), maxTime.strftime('%Y-%m-%d'), holidays = 
                     ['2018-01-01', '2018-01-15', '2018-02-19', '2018-03-30', '2018-05-28', '2018-07-04',
                      '2018-09-03', '2018-11-22', '2018-12-05', '2018-12-25',
                      '2019-01-01', '2019-01-21', '2019-02-18', '2019-04-19', '2019-05-27', '2019-07-04'])
calendar = np.busdaycalendar(holidays = 
                     ['2018-01-01', '2018-01-15', '2018-02-19', '2018-03-30', '2018-05-28', '2018-07-04',
                      '2018-09-03', '2018-11-22', '2018-12-05', '2018-12-25',
                      '2019-01-01', '2019-01-21', '2019-02-18', '2019-04-19', '2019-05-27', '2019-07-04'])
print(daysIncluded)

NUM_SAMPLES = len(timeStamps)

mean_impute = np.mean(denoisedVader)
std_impute = np.std(denoisedVader)

dates = np.arange(np.datetime64(minTime.strftime('%Y-%m-%d')), np.datetime64(maxTime.strftime('%Y-%m-%d')))
dates = dates[np.is_busday(dates, busdaycal = calendar)]

std_arr = np.empty(daysIncluded)
mean_arr = np.empty(daysIncluded)
vol_arr = np.empty(daysIncluded)
std_exists = np.empty(daysIncluded)
mean_exists = np.empty(daysIncluded)

imported_dates = np.empty(NUM_SAMPLES, dtype = 'datetime64[D]')
for d in range(NUM_SAMPLES):
    tempDate = np.datetime64(df.values[d, 0].strftime('%Y-%m-%d'))
    imported_dates[d] = tempDate

for i in range(daysIncluded):
    if i == daysIncluded-1:
        idx = (imported_dates == dates[i])
        tempVader = df.values[idx, 1]
    else:
        idx = np.where((imported_dates >= dates[i]) & (imported_dates < dates[i+1]))
        tempVader = df.values[idx, 1]
    if tempVader.size == 0:
        std_arr[i] = std_impute
        mean_arr[i] = mean_impute
        vol_arr[i] = 0
        std_exists[i] = 0
        mean_exists[i] = 0
    else:
        tempVader = tempVader[tempVader != 0]
        if tempVader.size == 0:
            std_arr[i] = std_impute
            mean_arr[i] = mean_impute
            vol_arr[i] = 0
            std_exists[i] = 0
            mean_exists[i] = 0
        else:
            std_arr[i] = np.std(tempVader)
            mean_arr[i] = np.mean(tempVader)
            vol_arr[i] = tempVader.size
            std_exists[i] = 1
            mean_exists[i] = 1
    
plt.pyplot.figure(figsize=(8, 8))
plt.pyplot.scatter(dates, vol_arr)
# Out:
# (28347, 2)
# 2019-07-10 22:57:00
# 380
# C:\Users\patel\Anaconda3\lib\site-packages\pandas\plotting\_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
output_df = pd.DataFrame({'dates':dates, 'vader_mean':mean_arr, 'vader_std':std_arr, 
                         'volume':vol_arr, 'mean_exist':mean_exists, 'std_exist':std_exists})
print(output_df)
# Out:
#          dates  vader_mean  vader_std  volume  mean_exist  std_exist
# 0   2018-01-03    0.351658   0.371627    19.0         1.0        1.0
# 1   2018-01-04    0.281543   0.390281    28.0         1.0        1.0
# 2   2018-01-05    0.346031   0.394035    71.0         1.0        1.0
# 3   2018-01-08    0.365527   0.348848    33.0         1.0        1.0
# 4   2018-01-09    0.279497   0.423766    32.0         1.0        1.0
# 5   2018-01-10    0.218420   0.351811    46.0         1.0        1.0
# 6   2018-01-11    0.232912   0.392800    41.0         1.0        1.0
# 7   2018-01-12    0.286874   0.432434    94.0         1.0        1.0
# 8   2018-01-16    0.352717   0.403136    35.0         1.0        1.0
# 9   2018-01-17    0.390595   0.323548    42.0         1.0        1.0
# 10  2018-01-18    0.410478   0.400911    41.0         1.0        1.0
# 11  2018-01-19    0.378544   0.428394    71.0         1.0        1.0
# 12  2018-01-22    0.324647   0.388126    38.0         1.0        1.0
# 13  2018-01-23    0.364544   0.453709    52.0         1.0        1.0
# 14  2018-01-24    0.378857   0.338714    53.0         1.0        1.0
# 15  2018-01-25    0.395816   0.349756    64.0         1.0        1.0
# 16  2018-01-26    0.403697   0.295582    70.0         1.0        1.0
# 17  2018-01-29    0.294865   0.469330    31.0         1.0        1.0
# 18  2018-01-30    0.299384   0.409306    55.0         1.0        1.0
# 19  2018-01-31    0.372547   0.378405    49.0         1.0        1.0
# 20  2018-02-01    0.271138   0.408652    60.0         1.0        1.0
# 21  2018-02-02    0.384236   0.402214    64.0         1.0        1.0
# 22  2018-02-05    0.500419   0.453586    43.0         1.0        1.0
# 23  2018-02-06    0.362722   0.409636    41.0         1.0        1.0
# 24  2018-02-07    0.465171   0.354707    51.0         1.0        1.0
# 25  2018-02-08    0.280742   0.456584    38.0         1.0        1.0
# 26  2018-02-09    0.277646   0.509818    50.0         1.0        1.0
# 27  2018-02-12    0.342694   0.410756    36.0         1.0        1.0
# 28  2018-02-13    0.259145   0.504936    47.0         1.0        1.0
# 29  2018-02-14    0.365023   0.366810    61.0         1.0        1.0
# ..         ...         ...        ...     ...         ...        ...
# 350 2019-05-28    0.303293   0.441174    27.0         1.0        1.0
# 351 2019-05-29    0.326063   0.476427    35.0         1.0        1.0
# 352 2019-05-30    0.516489   0.301458    46.0         1.0        1.0
# 353 2019-05-31    0.399971   0.434442    75.0         1.0        1.0
# 354 2019-06-03    0.271948   0.430431    42.0         1.0        1.0
# 355 2019-06-04    0.259690   0.392493    42.0         1.0        1.0
# 356 2019-06-05    0.375262   0.351956    50.0         1.0        1.0
# 357 2019-06-06    0.454118   0.271336    38.0         1.0        1.0
# 358 2019-06-07    0.259206   0.454595   195.0         1.0        1.0
# 359 2019-06-10    0.275449   0.449368    83.0         1.0        1.0
# 360 2019-06-11    0.391633   0.380776    73.0         1.0        1.0
# 361 2019-06-12    0.393429   0.378883    78.0         1.0        1.0
# 362 2019-06-13    0.232844   0.389756    48.0         1.0        1.0
# 363 2019-06-14    0.458632   0.362933    76.0         1.0        1.0
# 364 2019-06-17    0.394969   0.386405    52.0         1.0        1.0
# 365 2019-06-18    0.385586   0.401657    50.0         1.0        1.0
# 366 2019-06-19    0.458680   0.373583    51.0         1.0        1.0
# 367 2019-06-20    0.358715   0.414909    54.0         1.0        1.0
# 368 2019-06-21    0.426934   0.376796    89.0         1.0        1.0
# 369 2019-06-24    0.405358   0.397448    53.0         1.0        1.0
# 370 2019-06-25    0.384593   0.396447    61.0         1.0        1.0
# 371 2019-06-26    0.323726   0.430991    42.0         1.0        1.0
# 372 2019-06-27    0.265722   0.407818    40.0         1.0        1.0
# 373 2019-06-28    0.446184   0.311113    80.0         1.0        1.0
# 374 2019-07-01    0.323768   0.448470    31.0         1.0        1.0
# 375 2019-07-02    0.410527   0.274040    40.0         1.0        1.0
# 376 2019-07-03    0.414246   0.397428    74.0         1.0        1.0
# 377 2019-07-05    0.375654   0.367275    79.0         1.0        1.0
# 378 2019-07-08    0.335991   0.445991    45.0         1.0        1.0
# 379 2019-07-09    0.432414   0.378491    37.0         1.0        1.0
#
# [380 rows x 6 columns]

# %%
output_df.to_json('tweets_msft18-19_mod.json', orient='split')
