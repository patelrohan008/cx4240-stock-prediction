# %%
import json

# %%
# twitterscraper "#msft OR #microsoft  OR #windows OR #azure OR #xbox lang:en filter:verified" -bd 2019-01-01 -p 50 -o tweets_msft.json -ow
with open('tweets_amd2.json', 'r') as f:
    tweets = json.load(f, encoding = 'utf-8')

# %%
print(len(tweets))
print(len(tweets[0]))
print(tweets[0].keys())
# Out:
# 1869
# 10
# dict_keys(['fullname', 'html', 'id', 'likes', 'replies', 'retweets', 'text', 'timestamp', 'url', 'user'])

# %%
[tweet.pop('fullname') for tweet in tweets]
[tweet.pop('html') for tweet in tweets]
[tweet.pop('id') for tweet in tweets]
[tweet.pop('likes') for tweet in tweets]
[tweet.pop('replies') for tweet in tweets]
[tweet.pop('retweets') for tweet in tweets]
[tweet.pop('url') for tweet in tweets]
[tweet.pop('user') for tweet in tweets]
# Out:
# ['NatEyeInstitute',
#  'appleinsider',
#  'hutchison15',
#  'LowyatNET',
#  'AorusOfficial',
#  'sxbegle',
#  'ASUS_ROG',
#  'Softpedia',
#  'AMDRyzen',
#  'Matt_on_tech',
#  'HPE_SMB',
#  'Softpedia',
#  'AorusOfficial',
#  'ASUS',
#  'itworldca',
#  'HPE_Servers',
#  'ExpressTechie',
#  'DeccanHerald',
#  'Softpedia',
#  'CLXGaming',
#  'NatEyeInstitute',
#  'appleinsider',
#  'hutchison15',
#  'LowyatNET',
#  'AorusOfficial',
#  'sxbegle',
#  'ASUS_ROG',
#  'Softpedia',
#  'AMDRyzen',
#  'Matt_on_tech',
#  'HPE_SMB',
#  'Softpedia',
#  'AorusOfficial',
#  'ASUS',
#  'itworldca',
#  'HPE_Servers',
#  'ExpressTechie',
#  'DeccanHerald',
#  'Softpedia',
#  'CLXGaming',
#  'Softpedia',
#  'appleinsider',
#  'anshelsag',
#  'appleinsider',
#  'digitindia',
#  'SamCarvalho',
#  'tech2eets',
#  'chillblast',
#  'VelocityMicro',
#  'Radeon',
#  'heiseonline',
#  'AorusOfficial',
#  'AMDRyzen',
#  'golem',
#  'heiseonline',
#  'AMD_UK',
#  'NEHEP',
#  'MDMagazine',
#  'DellCares',
#  'AMDRyzen',
#  'theunlockr',
#  'AorusOfficial',
#  'ComputerBase',
#  'MDMagazine',
#  'AMDRyzen',
#  'MDMagazine',
#  'AMD_UK',
#  'MDMagazine',
#  'AMD_UK',
#  'MDMagazine',
#  'digitindia',
#  'thatdanhill',
#  'MDMagazine',
#  'MDMagazine',
#  'Moorfields',
#  'AvantGaming',
#  'MDMagazine',
#  'MDMagazine',
#  'Moorfields',
#  'Moorfields',
#  'cs_networks',
#  'Softpedia',
#  'physorg_com',
#  'tech2eets',
#  'Softpedia',
#  'Softpedia',
#  'MDMagazine',
#  'MDMagazine',
#  'AMD_UK',
#  'MDMagazine',
#  'digitindia',
#  'thatdanhill',
#  'MDMagazine',
#  'MDMagazine',
#  'Moorfields',
#  'AvantGaming',
#  'MDMagazine',
#  'MDMagazine',
#  'Moorfields',
#  'Moorfields',
#  'cs_networks',
#  'Softpedia',
#  'physorg_com',
#  'tech2eets',
#  'Softpedia',
#  'Softpedia',
#  'MDMagazine',
#  'MDMagazine',
#  'CIRMnews',
#  'MDMagazine',
#  'MDMagazine',
#  'The_MRC',
#  'NIHRresearch',
#  'NatureBiotech',
#  'NatureBiotech',
#  'dinopcuk',
#  'MDMagazine',
#  'AMDRyzen',
#  'killyourfm',
#  'MDMagazine',
#  'MDMagazine',
#  'mvizard',
#  'MDMagazine',
#  'AMD_UK',
#  'Battlefy',
#  'TheHackersNews',
#  'msiUSA',
#  'Spiceworks',
#  'ScanComputers',
#  'AMD_UK',
#  'ExpressTechie',
#  'CSOonline',
#  'siliconrepublic',
#  'kasperskyuk',
#  'ExpressTechie',
#  'TheRegister',
#  'Softpedia',
#  'AVADirect',
#  'Ttschersich',
#  'STcom',
#  'amelen',
#  'cs_networks',
#  'TheHackersNews',
#  'msiUSA',
#  'msitweets',
#  'ITPro',
#  'ScanComputers',
#  'data_nerd',
#  'travisWSN',
#  'travisWSN',
#  'AlienwareTech',
#  'MDMagazine',
#  'ScanComputers',
#  'LowyatNET',
#  '_BrightFocus',
#  'AMD_UK',
#  'AMDRyzen',
#  'MDMagazine',
#  'LowyatNET',
#  'tomshardware',
#  'LowyatNET',
#  'TechRadarIndia',
#  'TechRadarIndia',
#  'AVADirect',
#  'tomshardware',
#  'LowyatNET',
#  'AMD_UK',
#  'tomshardware',
#  'tomshardware',
#  'AVADirect',
#  'AMD_UK',
#  'AMD_Deutschland',
#  'wd_black',
#  'tomshardware',
#  'AVADirect',
#  'AMDRyzen',
#  'TuftsMedicalCtr',
#  'tomshardware',
#  'Newegg',
#  'appleinsider',
#  'ScanComputers',
#  'caro_milanesi',
#  'ians_india',
#  'ROG_ME',
#  'PCMagIndia',
#  'LowyatNET',
#  'ASUS',
#  'ASUS_ROG',
#  'ComputerBase',
#  'ComputerBase',
#  'LowyatNET',
#  'MikeFeibus',
#  'MikeFeibus',
#  'anshelsag',
#  'anshelsag',
#  'Moorfields',
#  'eToro',
#  'LowyatNET',
#  'Newegg',
#  'appleinsider',
#  'ScanComputers',
#  'caro_milanesi',
#  'ians_india',
#  'ROG_ME',
#  'PCMagIndia',
#  'LowyatNET',
#  'ASUS',
#  'ASUS_ROG',
#  'ComputerBase',
#  'ComputerBase',
#  'LowyatNET',
#  'MikeFeibus',
#  'MikeFeibus',
#  'anshelsag',
#  'anshelsag',
#  'Moorfields',
#  'eToro',
#  'LowyatNET',
#  'sammathews',
#  'LowyatNET',
#  '_BrightFocus',
#  'Moorfields',
#  'eToro',
#  'Moorfields',
#  'appleinsider',
#  '91mobiles',
#  'HPE_UKI',
#  'TheKoreaHerald',
#  'BGRIndia',
#  'LowyatNET',
#  'LowyatNET',
#  'Samsung',
#  'LowyatNET',
#  'ScanComputers',
#  'LowyatNET',
#  'AMDRyzen',
#  'CLXGaming',
#  'CRN',
#  'msiUSA',
#  'msitweets',
#  'richardlai',
#  'bequietofficial',
#  'Newegg',
#  'bequietofficial',
#  'eToro',
#  'LowyatNET',
#  'CRN',
#  'markhachman',
#  'ASUSAU',
#  'msiUSA',
#  'VahabzadehMD',
#  'AorusOfficial',
#  'msitweets',
#  'HYPEBEAST',
#  'chillblast',
#  'LowyatNET',
#  'AORUS_ANZ',
#  'LowyatNET',
#  'sascha_p',
#  'msitweets',
#  'tomshardware',
#  'tomshardware',
#  'tomshardware',
#  'anshelsag',
#  'tomshardware',
#  'markhachman',
#  'anshelsag',
#  'tomshardware',
#  'anshelsag',
#  'anshelsag',
#  'anshelsag',
#  'anshelsag',
#  'tomshardware',
#  'anshelsag',
#  'tomshardware',
#  'tomshardware',
#  'anshelsag',
#  'tomshardware',
#  'anshelsag',
#  'tomshardware',
#  'anshelsag',
#  'anshelsag',
#  'anshelsag',
#  'anshelsag',
#  'tomshardware',
#  'anshelsag',
#  'tomshardware',
#  'tomshardware',
#  'tomshardware',
#  'anshelsag',
#  'anshelsag',
#  'tomshardware',
#  'anshelsag',
#  'AMDRyzen',
#  'Vontobel_FP_FI',
#  'Vontobel_FP_FI',
#  'ComputerBase',
#  'LowyatNET',
#  'ASUS_ROG_ID',
#  'MDMagazine',
#  'UniofOxford',
#  'MDMagazine',
#  'ASUS_ROG',
#  'chillblast',
#  'ASUS_ROG_ID',
#  'MDMagazine',
#  'arstechnica',
#  'MDMagazine',
#  'AVADirect',
#  'RenderToken',
#  'MDMagazine',
#  'CLXGaming',
#  'AVADirect',
#  'AVADirect',
#  'Newegg',
#  'AVADirect',
#  'ORIGINPCCEO',
#  'ITPro',
#  'AVADirect',
#  'microcenter',
#  'chillblast',
#  'ASUS_ROG',
#  'ASUS_ROGUK',
#  'Newegg',
#  'ASUS_za',
#  'MDMagazine',
#  'arstechnica',
#  'MDMagazine',
#  'AVADirect',
#  'RenderToken',
#  'MDMagazine',
#  'CLXGaming',
#  'AVADirect',
#  'AVADirect',
#  'Newegg',
#  'AVADirect',
#  'ORIGINPCCEO',
#  'ITPro',
#  'AVADirect',
#  'microcenter',
#  'chillblast',
#  'ASUS_ROG',
#  'ASUS_ROGUK',
#  'Newegg',
#  'ASUS_za',
#  'Softpedia',
#  'AVADirect',
#  'GamesplanetUK',
#  'ASUS',
#  'medlineplus',
#  'AMDRyzen',
#  'LowyatNET',
#  'ASUSUSA',
#  'microcenter',
#  'fightblindness',
#  'TheHackersNews',
#  'kasperskyuk',
#  'dinopcuk',
#  'heiseonline',
#  'appleinsider',
#  'CLXGaming',
#  'MDMagazine',
#  'LowyatNET',
#  'Softpedia',
#  'BillRobersonDT',
#  'ASUSUSA',
#  'MDMagazine',
#  'Newegg',
#  'tech2eets',
#  'Softpedia',
#  'VelocityMicro',
#  'LowyatNET',
#  'AVADirect',
#  'ASUS_za',
#  'ASUS_ROG',
#  'ASUS_ROGUK',
#  'killyourfm',
#  'MDMagazine',
#  'AMDRyzen',
#  'LowyatNET',
#  'MDMagazine',
#  'AVADirect',
#  'AvantGaming',
#  'AMDRyzen',
#  'CRN',
#  'AVADirect',
#  'AMDRyzen',
#  'SklarBrothers',
#  'killyourfm',
#  'AVADirect',
#  'MDMagazine',
#  'Softpedia',
#  'killyourfm',
#  'AVADirect',
#  'AMDRyzen',
#  'AVADirect',
#  'AVADirect',
#  'AMDRyzen',
#  'MDMagazine',
#  'AVADirect',
#  'AVADirect',
#  'MDMagazine',
#  'AVADirect',
#  'derekmross',
#  'wd_black',
#  'MDMagazine',
#  'AMD_UK',
#  'EricTopol',
#  'AMDRyzen',
#  'JazeeraAirways',
#  'AVADirect',
#  'AMDRyzen',
#  'UKRI_News',
#  'dinopcuk',
#  'AMD_UK',
#  'AMDRyzen',
#  'Moorfields',
#  'msitweets',
#  'AMDGaming',
#  'AvantGaming',
#  'UKRI_News',
#  'fightblindness',
#  'LowyatNET',
#  'adnys',
#  'AMDRyzen',
#  'Matt_on_tech',
#  'MDMagazine',
#  'UKRI_News',
#  'MDMagazine',
#  'AMDRyzen',
#  'AMDRyzen',
#  'asalisbury',
#  'WatchMixer',
#  'AMDRyzen',
#  'AMDRyzen',
#  'HPE_Servers',
#  'AMD_UK',
#  'AMD_UK',
#  'msitweets',
#  'AMDCreators',
#  'MDMagazine',
#  'thatgrltrish',
#  'SomeGadgetGuy',
#  'AMD',
#  'AMD_UK',
#  'AORUS_Nordic',
#  'MDMagazine',
#  'AMDRyzen',
#  'TigerTopDeals',
#  'MDMagazine',
#  'AMDRyzen',
#  'asalisbury',
#  'WatchMixer',
#  'AMDRyzen',
#  'AMDRyzen',
#  'HPE_Servers',
#  'AMD_UK',
#  'AMD_UK',
#  'msitweets',
#  'AMDCreators',
#  'MDMagazine',
#  'thatgrltrish',
#  'SomeGadgetGuy',
#  'AMD',
#  'AMD_UK',
#  'AORUS_Nordic',
#  'MDMagazine',
#  'AMDRyzen',
#  'TigerTopDeals',
#  'MDMagazine',
#  'MDMagazine',
#  'channel_pro',
#  'AMD_UK',
#  'sxbegle',
#  'AMD_UK',
#  'Newegg',
#  'AMDCreators',
#  'AMDRyzen',
#  'Avira',
#  'msiUSA',
#  'AMDRyzen',
#  'TigerTopDeals',
#  'MDMagazine',
#  'ExpressTechie',
#  'AMD_UK',
#  'msitweets',
#  'Newegg',
#  'MwaveAu',
#  'AMD',
#  'Newegg',
#  'pushsquare',
#  'AMDRyzen',
#  'AMD',
#  'dancosta',
#  'VelocityMicro',
#  'LowyatNET',
#  'ExtremeTech',
#  'LisaSu',
#  'pushsquare',
#  'AMD_UK',
#  'AMDRyzen',
#  'AMDCreators',
#  'msiUSA',
#  'AORUS_ANZ',
#  'AMDCreators',
#  'AMDCreators',
#  'AORUS_Brasil',
#  'Newegg',
#  'AMDCreators',
#  'MDMagazine',
#  'msitweets',
#  'AorusOfficial',
#  'fightblindness',
#  'MDMagazine',
#  'LowyatNET',
#  'ASUSUSA',
#  'AORUS_Nordic',
#  'MDMagazine',
#  'MDMagazine',
#  'MDMagazine',
#  'm_j_miller',
#  'MDMagazine',
#  'msiUSA',
#  'AVADirect',
#  'MDMagazine',
#  'NEHEP',
#  'AMD_UK',
#  'MDMagazine',
#  'MDMagazine',
#  'Newegg',
#  'MDMagazine',
#  'MDMagazine',
#  'MDMagazine',
#  'HPE_Servers',
#  'AMD_UK',
#  'Moorfields',
#  'MDMagazine',
#  'MDMagazine',
#  'MDMagazine',
#  'MDMagazine',
#  'MDMagazine',
#  'AMDRyzen',
#  'MDMagazine',
#  'MDMagazine',
#  'MDMagazine',
#  'MDMagazine',
#  'PCGamesN',
#  'MDMagazine',
#  'ASUS_za',
#  'AMD_UK',
#  'RonnieTalbott',
#  'ASUSUSA',
#  'MDMagazine',
#  'Moorfields',
#  'MDMagazine',
#  'MDMagazine',
#  'MDMagazine',
#  'MDMagazine',
#  'Moorfields',
#  'AMDRyzen',
#  'Vertcoin',
#  'austinat',
#  'Moorfields',
#  'AMD_UK',
#  'BlindVeterans',
#  'AMDRyzen',
#  'tomshardware',
#  'dinopcuk',
#  'BlindVeterans',
#  'MAINGEAR',
#  'BlindVeterans',
#  'AMDRyzen',
#  'MDMagazine',
#  'ZAGrrl',
#  'ZAGrrl',
#  'AVADirect',
#  'MDMagazine',
#  'MDMagazine',
#  'Softpedia',
#  'Softpedia',
#  'MAINGEAR',
#  'Softpedia',
#  'Matt_on_tech',
#  'MDMagazine',
#  'BlindVeterans',
#  'AMDRyzen',
#  'tomshardware',
#  'dinopcuk',
#  'BlindVeterans',
#  'MAINGEAR',
#  'BlindVeterans',
#  'AMDRyzen',
#  'MDMagazine',
#  'ZAGrrl',
#  'ZAGrrl',
#  'AVADirect',
#  'MDMagazine',
#  'MDMagazine',
#  'Softpedia',
#  'Softpedia',
#  'MAINGEAR',
#  'Softpedia',
#  'Matt_on_tech',
#  'MDMagazine',
#  'MDMagazine',
#  'MDMagazine',
#  'MDMagazine',
#  'MDMagazine',
#  'LowyatNET',
#  'MDMagazine',
#  'tomshardware',
#  'MDMagazine',
#  'AMDRyzen',
#  'MDMagazine',
#  'MDMagazine',
#  'MDMagazine',
#  'Softpedia',
#  'MDMagazine',
#  'chillblast',
#  'tomshardware',
#  'AMD_UK',
#  'Barnacules',
#  'Softpedia',
#  'AMDRyzen',
#  'Softpedia',
#  'Softpedia',
#  'JazeeraAirways',
#  'LowyatNET',
#  'AMD_UK',
#  'MAINGEAR',
#  'MDMagazine',
#  'MDMagazine',
#  'AVADirect',
#  'MDMagazine',
#  'MDMagazine',
#  'MDMagazine',
#  'thefield_in',
#  'MDMagazine',
#  'AVADirect',
#  'MDMagazine',
#  'AMD_UK',
#  'Softpedia',
#  'ExpressTechie',
#  'digitindia',
#  'Softpedia',
#  'AcerAmerica',
#  'DigitalTrends',
#  'MDMagazine',
#  'VelocityMicro',
#  'digitindia',
#  'Alienware',
#  'MDMagazine',
#  'AMDRyzen',
#  'HushedApp',
#  'jonathanjosephs',
#  'FinancialXpress',
#  'Acer',
#  'appleinsider',
#  'tomshardware',
#  'LowyatNET',
#  'itworldca',
#  'brianjjackson',
#  'LowyatNET',
#  'Softpedia',
#  'BeyondTrust',
#  'Softpedia',
#  'AMDRyzen',
#  'dinopcuk',
#  'JohannesLenz',
#  'NatEyeInstitute',
#  'jgamet',
#  'DigitalKeith',
#  'lionelbarber',
#  'RedHat',
#  'juniperresearch',
#  'dft',
#  'DC_CyberProtect',
#  'iamhacker',
#  'techAU',
#  'appleinsider',
#  'AMD',
#  'AustinHeap',
#  'AMDRyzen',
#  'DigitalTrends',
#  'EricTopol',
#  'AMD_UK',
#  'LowyatNET',
#  'MDMagazine',
#  'AMDRyzen',
#  'AMD_UK',
#  'LowyatNET',
#  'MDMagazine',
#  'Softpedia',
#  'Softpedia',
#  'ASUSUSA',
#  'NatEyeInstitute',
#  'AMD_UK',
#  'AMD_UK',
#  'Moorfields',
#  'Vertcoin',
#  'MDMagazine',
#  'AMD_UK',
#  'LowyatNET',
#  'MDMagazine',
#  'MDMagazine',
#  'LowyatNET',
#  'LowyatNET',
#  'MDMagazine',
#  'AMDRyzen',
#  'AMD_UK',
#  'LowyatNET',
#  'MDMagazine',
#  'Softpedia',
#  'Softpedia',
#  'ASUSUSA',
#  'NatEyeInstitute',
#  'AMD_UK',
#  'AMD_UK',
#  'Moorfields',
#  'Vertcoin',
#  'MDMagazine',
#  'AMD_UK',
#  'LowyatNET',
#  'MDMagazine',
#  'MDMagazine',
#  'LowyatNET',
#  'LowyatNET',
#  'MDMagazine',
#  'insiderdotin',
#  'insiderdotin',
#  'AMD_UK',
#  'AMD_UK',
#  'LowyatNET',
#  'AMDRyzen',
#  '3djuegos',
#  'Moorfields',
#  'AMD_UK',
#  'insiderdotin',
#  'AMDRyzen',
#  'PCMagIndia',
#  'Vertcoin',
#  'Moorfields',
#  'Moorfields',
#  'microcenter',
#  'NEHEP',
#  'Moorfields',
#  'msiUSA',
#  'MDMagazine',
#  'insiderdotin',
#  'Softpedia',
#  'Vertcoin',
#  'AMD_UK',
#  'LowyatNET',
#  'Matt_on_tech',
#  'AMD_UK',
#  'LowyatNET',
#  'microcenter',
#  'insiderdotin',
#  'josephjett',
#  'killyourfm',
#  'NatEyeInstitute',
#  'killyourfm',
#  'MDMagazine',
#  'MDMagazine',
#  'digitindia',
#  'XilinxInc',
#  'msiUSA',
#  'microcenter',
#  'MDMagazine',
#  'AMD_UK',
#  'TheLancet',
#  'AMD_UK',
#  'MDMagazine',
#  'MDMagazine',
#  'TheLancet',
#  'TheLancet',
#  'AorusOfficial',
#  'ASUS_ROG',
#  'AVADirect',
#  'AMDCreators',
#  'allanface',
#  'allanface',
#  'ScanComputers',
#  'AMD_UK',
#  'digitindia',
#  'XilinxInc',
#  'msiUSA',
#  'microcenter',
#  'MDMagazine',
#  'AMD_UK',
#  'TheLancet',
#  'AMD_UK',
#  'MDMagazine',
#  'MDMagazine',
#  'TheLancet',
#  'TheLancet',
#  'AorusOfficial',
#  'ASUS_ROG',
#  'AVADirect',
#  'AMDCreators',
#  'allanface',
#  'allanface',
#  'ScanComputers',
#  'AMD_UK',
#  'NHSEnglandMidE',
#  'NHSEnglandMidE',
#  'Newegg',
#  'UCLAHealth',
#  'AMDCreators',
#  'NHSEnglandMidE',
#  'MDMagazine',
#  'Moorfields',
#  'AMDCreators',
#  'AlienwareTech',
#  'MDMagazine',
#  'AMDCreators',
#  'AMDRyzen',
#  'SwedeninIndia',
#  'UCLAHealth',
#  'Newegg',
#  'Softpedia',
#  'Softpedia',
#  'AMDRyzen',
#  'AMD_UK',
#  'msiUSA',
#  'AVADirect',
#  'AMD_UK',
#  'MDMagazine',
#  'AMD_UK',
#  'AorusOfficial',
#  'AVADirect',
#  'image_magazine',
#  'InWin',
#  'AMDRyzen',
#  'AMD_UK',
#  'ExpressTechie',
#  'AMD_UK',
#  'image_magazine',
#  'msitweets',
#  'AMD_UK',
#  'MassEyeAndEar',
#  'AMDRyzen',
#  'Barnacules',
#  'AMD_UK',
#  'LowyatNET',
#  'roisinmurphy',
#  'Newegg',
#  'AMDRyzen',
#  'IQOption',
#  'roisinmurphy',
#  'MDMagazine',
#  'roisinmurphy',
#  'roisinmurphy',
#  'roisinmurphy',
#  'roisinmurphy',
#  'Newegg',
#  'Newegg',
#  'MDMagazine',
#  'JazeeraAirways',
#  'MDMagazine',
#  'LowyatNET',
#  'roisinmurphy',
#  'Softpedia',
#  'MDMagazine',
#  'MDMagazine',
#  'roisinmurphy',
#  'Newegg',
#  'AMDRyzen',
#  'IQOption',
#  'roisinmurphy',
#  'MDMagazine',
#  'roisinmurphy',
#  'roisinmurphy',
#  'roisinmurphy',
#  'roisinmurphy',
#  'Newegg',
#  'Newegg',
#  'MDMagazine',
#  'JazeeraAirways',
#  'MDMagazine',
#  'LowyatNET',
#  'roisinmurphy',
#  'Softpedia',
#  'MDMagazine',
#  'MDMagazine',
#  'MDMagazine',
#  'MDMagazine',
#  'LowyatNET',
#  'MDMagazine',
#  'MDMagazine',
#  'LowyatNET',
#  'ASUSUSA',
#  'MDMagazine',
#  'MDMagazine',
#  'MDMagazine',
#  'MDMagazine',
#  'AVADirect',
#  'AMDRyzen',
#  'LowyatNET',
#  'AMDRyzen',
#  'roisinmurphy',
#  '_BrightFocus',
#  'MDMagazine',
#  'AVADirect',
#  '_BrightFocus',
#  'AlienwareTech',
#  'roisinmurphy',
#  'MDMagazine',
#  'ASUSTechMKTJJ',
#  'MDMagazine',
#  'MDMagazine',
#  'MDMagazine',
#  'AVADirect',
#  'fightblindness',
#  'fightblindness',
#  'fightblindness',
#  'ASUS_za',
#  'ASUSUSA',
#  'AMDRyzen',
#  'CRN',
#  'JazeeraAirways',
#  'ASUS_ROG',
#  'ASUSUSA',
#  'Newegg',
#  'markhachman',
#  'martin_fischer',
#  'Matt_on_tech',
#  'ASUS_ROGUK',
#  'ASUS_ROG',
#  'msiUSA',
#  'AVADirect',
#  'MDMagazine',
#  'AMD_UK',
#  'AMD_UK',
#  'LowyatNET',
#  'AVADirect',
#  'ASUS_ROGUK',
#  'AMD_UK',
#  'eToro',
#  'AorusOfficial',
#  'Softpedia',
#  'Avid',
#  'AVADirect',
#  'msiUSA',
#  'blausenmedical',
#  'ASUS_za',
#  'AorusOfficial',
#  'chillblast',
#  'DellCaresPRO',
#  'ScanComputers',
#  'LowyatNET',
#  'NHS',
#  'TheDivision_UK',
#  'ASUS_za',
#  'NHS',
#  'NHS',
#  'NHS',
#  'AMD_UK',
#  'eToro',
#  'AorusOfficial',
#  'Softpedia',
#  'Avid',
#  'AVADirect',
#  'msiUSA',
#  'blausenmedical',
#  'ASUS_za',
#  'AorusOfficial',
#  'chillblast',
#  'DellCaresPRO',
#  'ScanComputers',
#  'LowyatNET',
#  'NHS',
#  'TheDivision_UK',
#  'ASUS_za',
#  'NHS',
#  'NHS',
#  'NHS',
#  'ComputerBase',
#  'microcenter',
#  'DellCaresPRO',
#  'AVADirect',
#  'fightblindness',
#  'HPE_Servers',
#  'Kranti_Sambhav',
#  'ScanComputers',
#  'LowyatNET',
#  'ScanComputers',
#  'ScanComputers',
#  'alharding',
#  'CLXGaming',
#  'alharding',
#  'microcenter',
#  'HPE_Servers',
#  'ScanComputers',
#  'MDMagazine',
#  'joncampling',
#  'joncampling',
#  'MDMagazine',
#  'ComputerBase',
#  'umichmedicine',
#  ...]

# %%
print(tweets[0])
# Out:
# {'text': 'Faulty molecular master switch may contribute to #AMD. #NEINews. https://www.nih.gov/news-events/news-releases/faulty-molecular-master-switch-may-contribute-amd\xa0….pic.twitter.com/N7bfVM1X5f', 'timestamp': '2019-01-22T18:42:24'}

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

analyzer = SentimentIntensityAnalyzer()

# %%
#tweet = tweets[0]
#print(tweet)
#temp = analyzer.polarity_scores(tweet.pop('text'))
#temp_tweet['vader'] = temp.pop('compound')
for tweet in tweets:
    tweet['vader'] = (analyzer.polarity_scores(tweet.get('text'))).pop('compound')

# %%
print(tweets[0])
# Out:
# {'text': 'Faulty molecular master switch may contribute to #AMD. #NEINews. https://www.nih.gov/news-events/news-releases/faulty-molecular-master-switch-may-contribute-amd\xa0….pic.twitter.com/N7bfVM1X5f', 'timestamp': '2019-01-22T18:42:24', 'vader': -0.3182}

# %%
import numpy as np
import datetime

# %matplotlib inline
import matplotlib as plt

vaderScores = np.empty([len(tweets)])
timeStamps = np.empty([len(tweets)], dtype = datetime.datetime)
for i in range(len(tweets)):
    vaderScores[i] = tweets[i].get('vader')
    timeStamps[i] = datetime.datetime.strptime(tweets[i].get('timestamp'), '%Y-%m-%dT%H:%M:%S')
print('Mean: ' + str(np.mean(vaderScores)))
print('Standard deviation: ' + str(np.std(vaderScores)))
# Out:
# Mean: 0.2302215088282504
# Standard deviation: 0.38413194342576645

# %%
import pandas as pd

denoisedVader = vaderScores[vaderScores != 0]
vader_times = np.transpose(np.vstack((timeStamps, vaderScores)))
vader_times_Size = vader_times.shape
print(vader_times_Size)
df = pd.DataFrame(vader_times, columns=['date', 'vader'])
df.sort_values(by=['date'], ascending = True, inplace = True)

print(df.values[len(timeStamps)-1, 0])
minTime = df.values[0, 0]
maxTime = df.values[len(timeStamps)-1, 0]

daysIncluded = np.busday_count(minTime.strftime('%Y-%m-%d'), maxTime.strftime('%Y-%m-%d'), holidays = 
                     ['2018-01-01', '2018-01-15', '2018-02-19', '2018-03-30', '2018-05-28', '2018-07-04',
                      '2018-09-03', '2018-11-22', '2018-12-05', '2018-12-25',
                      '2019-01-01', '2019-01-21', '2019-02-18', '2019-04-19', '2019-05-27', '2019-07-04'])
calendar = np.busdaycalendar(holidays = 
                     ['2018-01-01', '2018-01-15', '2018-02-19', '2018-03-30', '2018-05-28', '2018-07-04',
                      '2018-09-03', '2018-11-22', '2018-12-05', '2018-12-25',
                      '2019-01-01', '2019-01-21', '2019-02-18', '2019-04-19', '2019-05-27', '2019-07-04'])
print(daysIncluded)

NUM_SAMPLES = len(timeStamps)

mean_impute = np.mean(denoisedVader)
std_impute = np.std(denoisedVader)

dates = np.arange(np.datetime64(minTime.strftime('%Y-%m-%d')), np.datetime64(maxTime.strftime('%Y-%m-%d')))
dates = dates[np.is_busday(dates, busdaycal = calendar)]

std_arr = np.empty(daysIncluded)
mean_arr = np.empty(daysIncluded)
vol_arr = np.empty(daysIncluded)
std_exists = np.empty(daysIncluded)
mean_exists = np.empty(daysIncluded)

imported_dates = np.empty(NUM_SAMPLES, dtype = 'datetime64[D]')
for d in range(NUM_SAMPLES):
    tempDate = np.datetime64(df.values[d, 0].strftime('%Y-%m-%d'))
    imported_dates[d] = tempDate

for i in range(daysIncluded):
    if i == daysIncluded-1:
        idx = (imported_dates == dates[i])
        tempVader = df.values[idx, 1]
    else:
        idx = np.where((imported_dates >= dates[i]) & (imported_dates < dates[i+1]))
        tempVader = df.values[idx, 1]
    if tempVader.size == 0:
        std_arr[i] = std_impute
        mean_arr[i] = mean_impute
        vol_arr[i] = 0
        std_exists[i] = 0
        mean_exists[i] = 0
    else:
        tempVader = tempVader[tempVader != 0]
        if tempVader.size == 0:
            std_arr[i] = std_impute
            mean_arr[i] = mean_impute
            vol_arr[i] = 0
            std_exists[i] = 0
            mean_exists[i] = 0
        else:
            std_arr[i] = np.std(tempVader)
            mean_arr[i] = np.mean(tempVader)
            vol_arr[i] = tempVader.size
            std_exists[i] = 1
            mean_exists[i] = 1
    
plt.pyplot.figure(figsize=(8, 8))
plt.pyplot.scatter(dates, vol_arr)
# Out:
# (1869, 2)
# 2019-07-09 22:40:27
# 381
# C:\Users\patel\Anaconda3\lib\site-packages\pandas\plotting\_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
output_df = pd.DataFrame({'dates':dates, 'vader_mean':mean_arr, 'vader_std':std_arr, 
                         'volume':vol_arr, 'mean_exist':mean_exists, 'std_exist':std_exists})
print(output_df)
# Out:
#          dates  vader_mean  vader_std  volume  mean_exist  std_exist
# 0   2018-01-02    0.610950   0.191050     2.0         1.0        1.0
# 1   2018-01-03    0.358033   0.285042     3.0         1.0        1.0
# 2   2018-01-04   -0.064500   0.422856     7.0         1.0        1.0
# 3   2018-01-05    0.162500   0.233501     3.0         1.0        1.0
# 4   2018-01-08    0.456325   0.370169     4.0         1.0        1.0
# 5   2018-01-09    0.301475   0.468432     4.0         1.0        1.0
# 6   2018-01-10   -0.009750   0.349750     2.0         1.0        1.0
# 7   2018-01-11   -0.226300   0.000000     1.0         1.0        1.0
# 8   2018-01-12    0.071356   0.460237     9.0         1.0        1.0
# 9   2018-01-16    0.359769   0.428931     0.0         0.0        0.0
# 10  2018-01-17   -0.111900   0.000000     1.0         1.0        1.0
# 11  2018-01-18    0.087800   0.314100     2.0         1.0        1.0
# 12  2018-01-19    0.148914   0.497854     7.0         1.0        1.0
# 13  2018-01-22   -0.690800   0.000000     1.0         1.0        1.0
# 14  2018-01-23   -0.067920   0.419430     5.0         1.0        1.0
# 15  2018-01-24    0.167633   0.654824     6.0         1.0        1.0
# 16  2018-01-25    0.510600   0.000000     2.0         1.0        1.0
# 17  2018-01-26    0.484700   0.025900     4.0         1.0        1.0
# 18  2018-01-29    0.509300   0.000000     1.0         1.0        1.0
# 19  2018-01-30    0.503000   0.252446     4.0         1.0        1.0
# 20  2018-01-31    0.258800   0.181600     2.0         1.0        1.0
# 21  2018-02-01   -0.093475   0.463217     4.0         1.0        1.0
# 22  2018-02-02    0.319767   0.394481     3.0         1.0        1.0
# 23  2018-02-05    0.529267   0.133832     3.0         1.0        1.0
# 24  2018-02-06    0.398900   0.559095     3.0         1.0        1.0
# 25  2018-02-07    0.226300   0.000000     1.0         1.0        1.0
# 26  2018-02-08    0.626100   0.000000     1.0         1.0        1.0
# 27  2018-02-09    0.093933   0.348299     6.0         1.0        1.0
# 28  2018-02-12    0.353167   0.569667     6.0         1.0        1.0
# 29  2018-02-13    0.080840   0.649334     5.0         1.0        1.0
# ..         ...         ...        ...     ...         ...        ...
# 351 2019-05-24    0.450452   0.368943    21.0         1.0        1.0
# 352 2019-05-28   -0.226300   0.000000     1.0         1.0        1.0
# 353 2019-05-29    0.603867   0.203847     3.0         1.0        1.0
# 354 2019-05-30    0.893200   0.000000     1.0         1.0        1.0
# 355 2019-05-31    0.832900   0.143700     2.0         1.0        1.0
# 356 2019-06-03    0.073100   0.367300     2.0         1.0        1.0
# 357 2019-06-04    0.341067   0.240581     3.0         1.0        1.0
# 358 2019-06-05    0.359769   0.428931     0.0         0.0        0.0
# 359 2019-06-06    0.359769   0.428931     0.0         0.0        0.0
# 360 2019-06-07    0.425880   0.146471     5.0         1.0        1.0
# 361 2019-06-10    0.612320   0.182233    10.0         1.0        1.0
# 362 2019-06-11    0.425857   0.243923    14.0         1.0        1.0
# 363 2019-06-12    0.359769   0.428931     0.0         0.0        0.0
# 364 2019-06-13    0.494767   0.135738     3.0         1.0        1.0
# 365 2019-06-14    0.359769   0.428931     0.0         0.0        0.0
# 366 2019-06-17    0.790250   0.109450     2.0         1.0        1.0
# 367 2019-06-18    0.826800   0.000000     1.0         1.0        1.0
# 368 2019-06-19    0.765000   0.000000     1.0         1.0        1.0
# 369 2019-06-20    0.602700   0.162300     2.0         1.0        1.0
# 370 2019-06-21    0.596600   0.032277     3.0         1.0        1.0
# 371 2019-06-24    0.735100   0.000000     1.0         1.0        1.0
# 372 2019-06-25    0.815267   0.081756     3.0         1.0        1.0
# 373 2019-06-26    0.208975   0.407786     4.0         1.0        1.0
# 374 2019-06-27    0.728925   0.135692     4.0         1.0        1.0
# 375 2019-06-28    0.213000   0.583491     5.0         1.0        1.0
# 376 2019-07-01    0.137200   0.666580     3.0         1.0        1.0
# 377 2019-07-02    0.422033   0.134789     3.0         1.0        1.0
# 378 2019-07-03    0.412637   0.415494     8.0         1.0        1.0
# 379 2019-07-05    0.534859   0.396218    17.0         1.0        1.0
# 380 2019-07-08    0.382400   0.643545     8.0         1.0        1.0
#
# [381 rows x 6 columns]

# %%
output_df.to_json('tweets_amd_mod.json', orient='split')
